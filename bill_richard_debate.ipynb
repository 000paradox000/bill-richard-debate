# %% [markdown]
# # Bill Gates and Richard Stallman Debate

# %% [markdown]
# ## Dependencies

# %%
# !git clone https://github.com/000paradox000/bill-richard-debate.git
# Out:
# fatal: destination path 'bill-richard-debate' already exists and is not an empty directory.

# %%
# !pip install -r bill-richard-debate/requirements.txt

# %% [markdown]
# ## Terminal

# %% [markdown]
# How to install ollama in the terminal?
#
# ```shell
# curl -fsSL https://ollama.com/install.sh | sh
# ollama serve &
# ```

# %%
# !echo "curl -fsSL https://ollama.com/install.sh | sh" > /tmp/install_ollama.sh
# !echo "" >> /tmp/install_ollama.sh
# !echo "ollama serve &" >> /tmp/install_ollama.sh
# !/bin/sh /tmp/install_ollama.sh

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
