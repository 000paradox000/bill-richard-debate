# %% [markdown]
# <a href="https://colab.research.google.com/github/000paradox000/bill-richard-debate/blob/main/bill_richard_debate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bill Gates and Richard Stallman Debate

# %% [markdown]
# ## Libraries

# %%
from pathlib import Path
# Out:
# Hello
